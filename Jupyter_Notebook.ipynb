# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Danielle** <br>
# Current: Analyst; Desired: Data Scientist

# %% [markdown]
# *I am interested in data science because it applies scientific methods to data analysis to move beyond descriptive information to predictive decision-making*

# %% [markdown]
# ### In Cell 5, I will add 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
#   <div class="alert alert-block alert-info"> <b>Wotntarnation</b> </div>
#
#       1. Wot
#       2. n
#       3. Tarnation
#
#
#   ![m_5b2196dd1b32949359804661.jpg](attachment:c585751a-2b69-406a-b37c-1ab08a6cba5e.jpg)
